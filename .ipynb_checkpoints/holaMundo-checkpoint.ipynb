# %% [markdown]
# # Primer Programa en Python

# %% [markdown]
# <img src="img/LogoITQ.jpg" width="500">

# %% [markdown]
# ## Hola mundo desde Python

# %% [markdown]
# <img src= "LogoPython.jpg">

# %% [markdown]
# * *Nombre:* Judith Piedra
# * *Fecha :* **23-06-2026**
# * *Repositorio:* <a href= "https://github.com/MerakiDevJP/machine1_23062026nocturno.git"> Link del repositorio Github</a>

# %% [markdown]
# Esta sección es para crear una función lambda donde calculo la raíz de un número

# %%
# Comentario en python saludando desde python
print("Hola mundo desde Python")
# Out:
# Hola mundo desde Python

# %%
# Ejecución comandos git para GitHub

# %% [markdown]
# <img src= "Respaldo git a github.jpg">
