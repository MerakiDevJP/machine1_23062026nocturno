# %% [markdown]
# # Primer Programa en Python
# ## Hola mundo desde Python
# * *Nombre:* Judith Piedra
# * *Fecha :* **23-06-2026**
# * *Repositorio:* <a href= ""> Link del repositorio Github</a>

# %%
# Comentario en python saludando desde python
print("Hola mundo desde Python")
# Out:
# Hola mundo desde Python
